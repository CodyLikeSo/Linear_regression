# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/home/cody/Code/Python/ML/ml_1/Class/Class_Abalone.csv')
df = df[['Length','Height']]

# %%
df.columns
# Out:
# Index(['Length', 'Height'], dtype='object')

# %%
plt.scatter(x=df.Length,y=df.Height,c='red')

# %%
df.fillna(method ='ffill', inplace = True)
print(len(df.Length))
print(len(df.Height))
# Out:
# 4177
# 4177
# /tmp/ipykernel_3368/2054664048.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method ='ffill', inplace = True)

# %%
plt.scatter(x=df.Length,y=df.Height,c='red')

# %%
X = np.array(df.Length).reshape(-1, 1)
y = np.array(df.Height).reshape(-1, 1)
X,y
# Out:
# (array([[0.455],
#         [0.35 ],
#         [0.53 ],
#         ...,
#         [0.6  ],
#         [0.625],
#         [0.71 ]]),
#  array([[0.095],
#         [0.09 ],
#         [0.135],
#         ...,
#         [0.205],
#         [0.15 ],
#         [0.195]]))

# %%
df.dropna(inplace = True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1)
model = LinearRegression()
model.fit(X_train, y_train)
print(model.score(X_train, y_train))
# Out:
# 0.6848389810184583

# %%
pred = model.predict(X_train)

plt.scatter(X_train, y_train, color ='b')
plt.plot(X_train, pred, color ='k')
 
plt.show()
